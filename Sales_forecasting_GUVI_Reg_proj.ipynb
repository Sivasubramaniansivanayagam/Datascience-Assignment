# %% [markdown]
# <a href="https://colab.research.google.com/github/Sivasubramaniansivanayagam/Datascience-Assignment/blob/main/Sales_forecasting_GUVI_Reg_proj.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
df_store=pd.read_csv("/content/drive/MyDrive/Sales Forecasting/stores.csv")

# %%
print("shape is",df_store.shape)
df_store.head()
# Out:
# shape is (45, 3)
#    Store Type    Size
# 0      1    A  151315
# 1      2    A  202307
# 2      3    B   37392
# 3      4    A  205863
# 4      5    B   34875

# %%
plt.style.use("fivethirtyeight")
gp_store=df_store.groupby("Type")["Size"].sum()
gp_store.plot.pie(autopct='%.2f%%',explode=[0.1,0,0])
plt.legend(loc=(1,0.6),fontsize=12)
plt.title("Store size")
plt.axis("equal")
plt.show()
# px.pie(gp_store,values=gp_store.values,names=gp_store.index,title="Store size")

# %%
# boxplot for sizes of types of stores
plt.figure(figsize=(5,3))
px.box(df_store,x='Type', y='Size',color="Type")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="e30635ee-9282-4678-a270-18012652c3ae" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e30635ee-9282-4678-a270-18012652c3ae")) {                    Plotly.newPlot(                        "e30635ee-9282-4678-a270-18012652c3ae",                        [{"alignmentgroup":"True","hovertemplate":"Type=%{x}<br>Size=%{y}<extra></extra>","legendgroup":"A","marker":{"color":"#636efa"},"name":"A","notched":false,"offsetgroup":"A","orientation":"v","showlegend":true,"x":["A","A","A","A","A","A","A","A","A","A","A","A","A","A","A","A","A","A","A","A","A","A"],"x0":" ","xaxis":"x","y":[151315,202307,205863,202505,155078,207499,219622,200898,203819,203742,203819,152513,204184,206302,203750,203007,39690,158114,39910,184109,155083,196321],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"Type=%{x}<br>Size=%{y}<extra></extra>","legendgroup":"B","marker":{"color":"#EF553B"},"name":"B","notched":false,"offsetgroup":"B","orientation":"v","showlegend":true,"x":["B","B","B","B","B","B","B","B","B","B","B","B","B","B","B","B","B"],"x0":" ","xaxis":"x","y":[37392,34875,70713,125833,126512,112238,123737,57197,93188,120653,140167,119557,114533,128107,93638,103681,118221],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"Type=%{x}<br>Size=%{y}<extra></extra>","legendgroup":"C","marker":{"color":"#00cc96"},"name":"C","notched":false,"offsetgroup":"C","orientation":"v","showlegend":true,"x":["C","C","C","C","C","C"],"x0":" ","xaxis":"x","y":[42988,39910,39690,39690,41062,39910],"y0":" ","yaxis":"y","type":"box"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"# ...

# %%
sns.boxplot(data=df_store,x='Type', y='Size')

# %%
plt.figure(figsize=(8,6))
sns.pairplot(df_store,vars=['Store','Type','Size'])

# %% [markdown]
# Observation:
#
# There are 45 stores in total.
#
# There are a total of 3 types of stores: Type A, B and C.
#
# By boxplot and piechart, we can say that type A store is the largest store and C is the smallest
#
# There is no overlapped area in size among A, B, and C.

# %%
# Importing Train and test data
dftrain=pd.read_csv("/content/drive/MyDrive/Sales Forecasting/train.csv")
dftest=pd.read_csv("/content/drive/MyDrive/Sales Forecasting/test.csv")

# %%
print(f"shape of train data {dftrain.shape}")
dftrain.head()
# Out:
# shape of train data (421570, 5)
#    Store  Dept        Date  Weekly_Sales  IsHoliday
# 0      1     1  2010-02-05      24924.50      False
# 1      1     1  2010-02-12      46039.49       True
# 2      1     1  2010-02-19      41595.55      False
# 3      1     1  2010-02-26      19403.54      False
# 4      1     1  2010-03-05      21827.90      False

# %%
print(f"shape of test data {dftest.shape}")
dftest.head()
# Out:
# shape of test data (115064, 4)
#    Store  Dept        Date  IsHoliday
# 0      1     1  2012-11-02      False
# 1      1     1  2012-11-09      False
# 2      1     1  2012-11-16      False
# 3      1     1  2012-11-23       True
# 4      1     1  2012-11-30      False

# %%
dftrain.info() , dftest.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 421570 entries, 0 to 421569
# Data columns (total 5 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Store         421570 non-null  int64
#  1   Dept          421570 non-null  int64
#  2   Date          421570 non-null  object
#  3   Weekly_Sales  421570 non-null  float64
#  4   IsHoliday     421570 non-null  bool
# dtypes: bool(1), float64(1), int64(2), object(1)
# memory usage: 13.3+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 115064 entries, 0 to 115063
# Data columns (total 4 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   Store      115064 non-null  int64
#  1   Dept       115064 non-null  int64
#  2   Date       115064 non-null  object
#  3   IsHoliday  115064 non-null  bool
# dtypes: bool(1), int64(2), object(1)
# memory usage: 2.7+ MB
# (None, None)

# %%
# converting to date time object
dftrain["Date"]=pd.to_datetime(dftrain["Date"])
dftest["Date"]=pd.to_datetime(dftest["Date"])

# %%
dftrain["Week"]=dftrain["Date"].dt.isocalendar().week
dftest["Week"]=dftest["Date"].dt.isocalendar().week

# %%
dftrain["Month"]=dftrain["Date"].dt.month
dftest["Month"]=dftest["Date"].dt.month

dftrain["Year"]=dftrain["Date"].dt.year
dftest["Year"]=dftest["Date"].dt.year

dftrain["Day"]=dftrain["Date"].dt.day
dftest["Day"]=dftest["Date"].dt.day

dftrain["Dayofweek"]=dftrain["Date"].dt.dayofweek
dftest["Dayofweek"]=dftest["Date"].dt.dayofweek

# %%
dftrain.head(),dftest.head()
# Out:
# (   Store  Dept       Date  Weekly_Sales  IsHoliday  Week  Month  Year  Day  \
#  0      1     1 2010-02-05      24924.50      False     5      2  2010    5
#  1      1     1 2010-02-12      46039.49       True     6      2  2010   12
#  2      1     1 2010-02-19      41595.55      False     7      2  2010   19
#  3      1     1 2010-02-26      19403.54      False     8      2  2010   26
#  4      1     1 2010-03-05      21827.90      False     9      3  2010    5
#
#     Dayofweek
#  0          4
#  1          4
#  2          4
#  3          4
#  4          4  ,
#     Store  Dept       Date  IsHoliday  Week  Month  Year  Day  Dayofweek
#  0      1     1 2012-11-02      False    44     11  2012    2          4
#  1      1     1 2012-11-09      False    45     11  2012    9          4
#  2      1     1 2012-11-16      False    46     11  2012   16          4
#  3      1     1 2012-11-23       True    47     11  2012   23          4
#  4      1     1 2012-11-30      False    48     11  2012   30          4)

# %%
dftrain["IsHoliday"].value_counts()
# Out:
# False    391909
# True      29661
# Name: IsHoliday, dtype: int64

# %%
dftrain["IsHoliday"].value_counts().plot.bar()

# %%
dftrain.groupby("IsHoliday")["Weekly_Sales"].sum()
# Out:
# IsHoliday
# False    6.231919e+09
# True     5.052996e+08
# Name: Weekly_Sales, dtype: float64

# %%
dftrain.nunique()
# Out:
# Store               45
# Dept                81
# Date               143
# Weekly_Sales    359464
# IsHoliday            2
# Week                52
# Month               12
# Year                 3
# Day                 31
# Dayofweek            1
# dtype: int64

# %%
dftrain.plot(kind='line', x='Dept', y='Weekly_Sales', alpha=1,fig=(4,4))

# %% [markdown]
# Observation:
#
# Sales in holiday is a good than normal days as the overall sales amount is near.
#
# From this plot, we notice Deptartment with the highest sales lies between Dept 60 and 80

# %%
# loading features csv
df_feat=pd.read_csv("/content/drive/MyDrive/Sales Forecasting/features.csv")

# %%
print(f"shape of features data {df_feat.shape}")
df_feat.head()
# Out:
# shape of features data (8190, 12)
#    Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0      1  2010-02-05        42.31       2.572        NaN        NaN
# 1      1  2010-02-12        38.51       2.548        NaN        NaN
# 2      1  2010-02-19        39.93       2.514        NaN        NaN
# 3      1  2010-02-26        46.63       2.561        NaN        NaN
# 4      1  2010-03-05        46.50       2.625        NaN        NaN
#
#    MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday
# 0        NaN        NaN        NaN  211.096358         8.106      False
# 1        NaN        NaN        NaN  211.242170         8.106       True
# 2        NaN        NaN        NaN  211.289143         8.106      False
# 3        NaN        NaN        NaN  211.319643         8.106      False
# 4        NaN        NaN        NaN  211.350143         8.106      False

# %%
# converting to date time object
df_feat["Date"]=pd.to_datetime(df_feat["Date"])

# %% [markdown]
# Merge Features data with train and test data

# %%
train_with_feat = pd.merge_asof(dftrain,df_feat, on='Store',by='Date')
test_with_feat = pd.merge_asof(dftest, df_feat, on='Store',by='Date')

# %%
train_with_feat.head()
# Out:
#    Store  Dept       Date  Weekly_Sales  IsHoliday_x  Week  Month  Year  Day  \
# 0      1     1 2010-02-05      24924.50        False     5      2  2010    5
# 1      1     1 2010-02-12      46039.49         True     6      2  2010   12
# 2      1     1 2010-02-19      41595.55        False     7      2  2010   19
# 3      1     1 2010-02-26      19403.54        False     8      2  2010   26
# 4      1     1 2010-03-05      21827.90        False     9      3  2010    5
#
#    Dayofweek  Temperature  Fuel_Price  MarkDown1  MarkDown2  MarkDown3  \
# 0          4        42.31       2.572        NaN        NaN        NaN
# 1          4        38.51       2.548        NaN        NaN        NaN
# 2          4        39.93       2.514        NaN        NaN        NaN
# 3          4        46.63       2.561        NaN        NaN        NaN
# 4          4        46.50       2.625        NaN        NaN        NaN
#
#    MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday_y
# 0        NaN        NaN  211.096358         8.106        False
# 1        NaN        NaN  211.242170         8.106         True
# 2        NaN        NaN  211.289143         8.106        False
# 3        NaN        NaN  211.319643         8.106        False
# 4        NaN        NaN  211.350143         8.106        False

# %%
#merge all the features
train_with_feat_new = pd.merge(train_with_feat,df_store)
test_with_feat_new = pd.merge(test_with_feat,df_store)

# %%
train_with_feat_new.head()
# Out:
#    Store  Dept       Date  Weekly_Sales  IsHoliday_x  Week  Month  Year  Day  \
# 0      1     1 2010-02-05      24924.50        False     5      2  2010    5
# 1      1     1 2010-02-12      46039.49         True     6      2  2010   12
# 2      1     1 2010-02-19      41595.55        False     7      2  2010   19
# 3      1     1 2010-02-26      19403.54        False     8      2  2010   26
# 4      1     1 2010-03-05      21827.90        False     9      3  2010    5
#
#    Dayofweek  ...  MarkDown1  MarkDown2  MarkDown3  MarkDown4  MarkDown5  \
# 0          4  ...        NaN        NaN        NaN        NaN        NaN
# 1          4  ...        NaN        NaN        NaN        NaN        NaN
# 2          4  ...        NaN        NaN        NaN        NaN        NaN
# 3          4  ...        NaN        NaN        NaN        NaN        NaN
# 4          4  ...        NaN        NaN        NaN        NaN        NaN
#
#           CPI  Unemployment  IsHoliday_y  Type    Size
# 0  211.096358         8.106        False     A  151315
# 1  211.242170         8.106         True     A  151315
# 2  211.289143         8.106        False     A  151315
# 3  211.319643         8.106        False     A  151315
# 4  211.350143         8.106        False     A  151315
#
# [5 rows x 22 columns]

# %%
train_with_feat_new.shape
# Out:
# (421570, 22)

# %%
#drop the dublicate of IsHoliday column
train_with_feat = train_with_feat_new.drop(columns=['IsHoliday_x'])
test_with_feat = test_with_feat_new.drop(columns=['IsHoliday_x'])

#let's rename the IsHoliday_y column to IsHoliday
train_with_feat = train_with_feat.rename(columns={"IsHoliday_y": "IsHoliday"})
test_with_feat= test_with_feat.rename(columns={"IsHoliday_y": "IsHoliday"})

# %%
train_with_feat.head()
# Out:
#    Store  Dept       Date  Weekly_Sales  Week  Month  Year  Day  Dayofweek  \
# 0      1     1 2010-02-05      24924.50     5      2  2010    5          4
# 1      1     1 2010-02-12      46039.49     6      2  2010   12          4
# 2      1     1 2010-02-19      41595.55     7      2  2010   19          4
# 3      1     1 2010-02-26      19403.54     8      2  2010   26          4
# 4      1     1 2010-03-05      21827.90     9      3  2010    5          4
#
#    Temperature  ...  MarkDown1  MarkDown2  MarkDown3  MarkDown4  MarkDown5  \
# 0        42.31  ...        NaN        NaN        NaN        NaN        NaN
# 1        38.51  ...        NaN        NaN        NaN        NaN        NaN
# 2        39.93  ...        NaN        NaN        NaN        NaN        NaN
# 3        46.63  ...        NaN        NaN        NaN        NaN        NaN
# 4        46.50  ...        NaN        NaN        NaN        NaN        NaN
#
#           CPI  Unemployment  IsHoliday  Type    Size
# 0  211.096358         8.106      False     A  151315
# 1  211.242170         8.106       True     A  151315
# 2  211.289143         8.106      False     A  151315
# 3  211.319643         8.106      False     A  151315
# 4  211.350143         8.106      False     A  151315
#
# [5 rows x 21 columns]

# %%
train_with_feat["IsHoliday"].value_counts()
# Out:
# False    391909
# True      29661
# Name: IsHoliday, dtype: int64

# %%
# changing IsHoliday column with Flase to be 0 and True to be 1

train_with_feat["IsHoliday"]=train_with_feat["IsHoliday"].map({False:0,True:1})
test_with_feat["IsHoliday"]=test_with_feat["IsHoliday"].map({False:0,True:1})

# %%
train_with_feat["IsHoliday"].value_counts()
# Out:
# 0    391909
# 1     29661
# Name: IsHoliday, dtype: int64

# %%
train_with_feat["Type"].value_counts()
# Out:
# A    215478
# B    163495
# C     42597
# Name: Type, dtype: int64

# %%
# Ranking Type column with A to be 1 , B to be 2 and C to be 3

train_with_feat["Type"]=train_with_feat["Type"].map({"A":1,"B":2,"C":3})
test_with_feat["Type"]=test_with_feat["Type"].map({"A":1,"B":2,"C":3})

# %%
train_with_feat["Type"].value_counts()
# Out:
# 1    215478
# 2    163495
# 3     42597
# Name: Type, dtype: int64

# %%
train_with_feat.describe()
# Out:
#                Store           Dept   Weekly_Sales           Week  \
# count  421570.000000  421570.000000  421570.000000  421570.000000
# mean       22.200546      44.260317   15981.258123      25.826762
# std        12.785297      30.492054   22711.183519      14.151887
# min         1.000000       1.000000   -4988.940000       1.000000
# 25%        11.000000      18.000000    2079.650000      14.000000
# 50%        22.000000      37.000000    7612.030000      26.000000
# 75%        33.000000      74.000000   20205.852500      38.000000
# max        45.000000      99.000000  693099.360000      52.000000
#
#                Month           Year            Day  Dayofweek    Temperature  \
# count  421570.000000  421570.000000  421570.000000   421570.0  421570.000000
# mean        6.449510    2010.968591      15.673131        4.0      60.090059
# std         3.243217       0.796876       8.753549        0.0      18.447931
# min         1.000000    2010.000000       1.000000        4.0      -2.060000
# 25%         4.000000    2010.000000       8.000000        4.0      46.680000
# 50%         6.000000    2011.000000      16.000000        4.0      62.090000
# 75%         9.000000    2012.000000      23.000000        4.0      74.280000
# max        12.000000    2012.000000      31.000000        4.0     100.140000
#
#           Fuel_Price      MarkDown1      MarkDown2      MarkDown3  \
# count  421570.000000  150681.000000  111248.000000  137091.000000
# mean        3.361027    7246.420196    3334.628621    1439.421384
# std         0.458515    8291.221345    9475.357325    9623.078290
# min         2.472000       0.270000    -265.760000     -29.100000
# 25%         2.933000    2240.270000      41.600000       5.080000
# 50%         3.452000    5347.450000     192.000000      24.600000
# 75%         3.738000    9210.900000    1926.940000     103.990000
# max         4.468000   88646.760000  104519.540000  141630.610000
#
#            MarkDown4      MarkDown5            CPI   Unemployment  \
# count  134967.000000  151432.000000  421570.000000  421570.000000
# mean     3383.168256    4628.975079     171.201947       7.960289
# std      6292.384031    5962.887455      39.159276       1.863296
# min         0.220000     135.160000     126.064000       3.879000
# 25%       504.220000    1878.440000     132.022667       6.891000
# 50%      1481.310000    3359.450000     182.318780       7.866000
# 75%      3595.040000    5563.800000     212.416993       8.572000
# max     67474.850000  108519.280000     227.232807      14.313000
#
#            IsHoliday           Type           Size
# count  421570.000000  421570.000000  421570.000000
# mean        0.070358       1.589912  136727.915739
# std         0.255750       0.666337   60980.583328
# min         0.000000       1.000000   34875.000000
# 25%         0.000000       1.000000   93638.000000
# 50%         0.000000       1.000000  140167.000000
# 75%         0.000000       2.000000  202505.000000
# max         1.000000       3.000000  219622.000000

# %%
gp1=train_with_feat.groupby("Year")["Weekly_Sales"].sum()
gp1
# Out:
# Year
# 2010    2.288886e+09
# 2011    2.448200e+09
# 2012    2.000133e+09
# Name: Weekly_Sales, dtype: float64

# %%
px.line(gp1,x=gp1.index,y=gp1.values,title="Weekly_sales by year")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="3a9b6007-7223-4524-bcf3-f3da32a6f5f7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3a9b6007-7223-4524-bcf3-f3da32a6f5f7")) {                    Plotly.newPlot(                        "3a9b6007-7223-4524-bcf3-f3da32a6f5f7",                        [{"hovertemplate":"Year=%{x}<br>y=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":[2010,2011,2012],"xaxis":"x","y":[2288886120.41,2448200007.35,2000132859.35],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}} ...

# %% [markdown]
# Train and test dataset Correlation

# %%
train_with_feat.shape
# Out:
# (421570, 21)

# %%
plt.figure(figsize=(15, 10))
sns.heatmap(train_with_feat.corr(),annot=True)

# %%
test_with_feat.shape
# Out:
# (115064, 20)

# %%
plt.style.use("fivethirtyeight")
plt.figure(figsize=(15, 10))
sns.heatmap(test_with_feat.corr(),annot=True)

# %% [markdown]
# Filling Missing data

# %%
train_with_feat.isna().sum(),"********",test_with_feat.isna().sum()
# Out:
# (Store                0
#  Dept                 0
#  Date                 0
#  Weekly_Sales         0
#  Week                 0
#  Month                0
#  Year                 0
#  Day                  0
#  Dayofweek            0
#  Temperature          0
#  Fuel_Price           0
#  MarkDown1       270889
#  MarkDown2       310322
#  MarkDown3       284479
#  MarkDown4       286603
#  MarkDown5       270138
#  CPI                  0
#  Unemployment         0
#  IsHoliday            0
#  Type                 0
#  Size                 0
#  dtype: int64, '********', Store               0
#  Dept                0
#  Date                0
#  Week                0
#  Month               0
#  Year                0
#  Day                 0
#  Dayofweek           0
#  Temperature         0
#  Fuel_Price          0
#  MarkDown1         149
#  MarkDown2       28627
#  MarkDown3        9829
#  MarkDown4       12888
#  MarkDown5           0
#  CPI             38162
#  Unemployment    38162
#  IsHoliday           0
#  Type                0
#  Size                0
#  dtype: int64)

# %%
# there was no markdown so filling it with zero

train_with_feat["MarkDown1"]=train_with_feat["MarkDown1"].fillna(0)
train_with_feat["MarkDown2"]=train_with_feat["MarkDown2"].fillna(0)
train_with_feat["MarkDown3"]=train_with_feat["MarkDown3"].fillna(0)
train_with_feat["MarkDown4"]=train_with_feat["MarkDown4"].fillna(0)
train_with_feat["MarkDown5"]=train_with_feat["MarkDown5"].fillna(0)

# %%
# for test
test_with_feat["MarkDown1"]=test_with_feat["MarkDown1"].fillna(0)
test_with_feat["MarkDown2"]=test_with_feat["MarkDown2"].fillna(0)
test_with_feat["MarkDown3"]=test_with_feat["MarkDown3"].fillna(0)
test_with_feat["MarkDown4"]=test_with_feat["MarkDown4"].fillna(0)
test_with_feat["MarkDown5"]=test_with_feat["MarkDown5"].fillna(0)

# filling CPI and Unemployment with mean 

test_with_feat["CPI"]=test_with_feat["CPI"].fillna(test_with_feat["CPI"].mean())
test_with_feat["Unemployment"]=test_with_feat["Unemployment"].fillna(test_with_feat["Unemployment"].mean())

# %%
test_with_feat.describe()
# Out:
#                Store           Dept           Week          Month  \
# count  115064.000000  115064.000000  115064.000000  115064.000000
# mean       22.238207      44.339524      23.050963       5.729855
# std        12.809930      30.656410      15.750407       3.590331
# min         1.000000       1.000000       1.000000       1.000000
# 25%        11.000000      18.000000      10.000000       3.000000
# 50%        22.000000      37.000000      20.000000       5.000000
# 75%        33.000000      74.000000      30.000000       7.000000
# max        45.000000      99.000000      52.000000      12.000000
#
#                 Year            Day  Dayofweek    Temperature     Fuel_Price  \
# count  115064.000000  115064.000000   115064.0  115064.000000  115064.000000
# mean     2012.767182      15.583536        4.0      53.941804       3.581546
# std         0.422629       8.844900        0.0      18.724153       0.239442
# min      2012.000000       1.000000        4.0      -7.290000       2.872000
# 25%      2013.000000       8.000000        4.0      39.820000       3.431000
# 50%      2013.000000      15.000000        4.0      54.470000       3.606000
# 75%      2013.000000      23.000000        4.0      67.350000       3.766000
# max      2013.000000      31.000000        4.0     101.950000       4.125000
#
#            MarkDown1      MarkDown2      MarkDown3      MarkDown4  \
# count  115064.000000  115064.000000  115064.000000  115064.000000
# mean     7679.259430    2805.049619    2197.811964    2980.298267
# std     10695.406505    7392.556347   13183.888087    7212.030921
# min     -2781.450000     -35.740000    -179.260000       0.000000
# 25%      1963.550000       0.000000       7.770000      70.370000
# 50%      4828.720000     316.880000      60.000000     600.580000
# 75%      9427.410000    1575.850000     244.200000    2627.850000
# max    103184.980000   71074.170000  149483.310000   65344.640000
#
#            MarkDown5            CPI   Unemployment      IsHoliday  \
# count  115064.000000  115064.000000  115064.000000  115064.000000
# mean     3922.681189     176.961347       6.868733       0.077592
# std     19445.150745      33.714479       1.294483       0.267529
# min      -185.170000     131.236226       3.684000       0.000000
# 25%      1309.300000     138.900429       6.228000       0.000000
# 50%      2390.430000     176.961347       6.868733       0.000000
# 75%      4227.270000     201.212230       7.293000       0.000000
# max    771448.100000     228.976456      10.199000       1.000000
#
#                 Type           Size
# count  115064.000000  115064.000000
# mean        1.592731  136497.688921
# std         0.668876   61106.926438
# min         1.000000   34875.000000
# 25%         1.000000   93638.000000
# 50%         1.000000  140167.000000
# 75%         2.000000  202505.000000
# max         3.000000  219622.000000

# %%
# checking once again if an missing values
train_with_feat.isna().sum(),"********",test_with_feat.isna().sum()
# Out:
# (Store           0
#  Dept            0
#  Date            0
#  Weekly_Sales    0
#  Week            0
#  Month           0
#  Year            0
#  Day             0
#  Dayofweek       0
#  Temperature     0
#  Fuel_Price      0
#  MarkDown1       0
#  MarkDown2       0
#  MarkDown3       0
#  MarkDown4       0
#  MarkDown5       0
#  CPI             0
#  Unemployment    0
#  IsHoliday       0
#  Type            0
#  Size            0
#  dtype: int64, '********', Store           0
#  Dept            0
#  Date            0
#  Week            0
#  Month           0
#  Year            0
#  Day             0
#  Dayofweek       0
#  Temperature     0
#  Fuel_Price      0
#  MarkDown1       0
#  MarkDown2       0
#  MarkDown3       0
#  MarkDown4       0
#  MarkDown5       0
#  CPI             0
#  Unemployment    0
#  IsHoliday       0
#  Type            0
#  Size            0
#  dtype: int64)

# %% [markdown]
# Define training and testing set

# %%
train_with_feat.columns
# Out:
# Index(['Store', 'Dept', 'Date', 'Weekly_Sales', 'Week', 'Month', 'Year', 'Day',
#        'Dayofweek', 'Temperature', 'Fuel_Price', 'MarkDown1', 'MarkDown2',
#        'MarkDown3', 'MarkDown4', 'MarkDown5', 'CPI', 'Unemployment',
#        'IsHoliday', 'Type', 'Size'],
#       dtype='object')

# %%
# X and y for train
X=train_with_feat.drop(columns=["Date","Weekly_Sales"])
y=train_with_feat["Weekly_Sales"]

# %%
X=np.array(X)
y=np.array(y)

# %%
# for test
X_test=test_with_feat.drop(columns=["Date"])

# %%
X_test_data=np.array(X_test)

# %%
X.shape,X_test.shape
# Out:
# ((421570, 19), (115064, 19))

# %%
y.shape
# Out:
# (421570,)

# %% [markdown]
# Machine Learning Models

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=0)

# %% [markdown]
# TRAIN AN LINEAR REGRESSOR MODEL

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import classification_report,accuracy_score
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error, accuracy_score
from math import sqrt

# %%
linear_regmodel=LinearRegression()
linear_regmodel.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
accuracy_LinearRegression = linear_regmodel.score(X_test, y_test)
accuracy_LinearRegression
# Out:
# 0.08831467380915592

# %% [markdown]
# TRAIN AN DECISIONTREE REGRESSOR MODEL

# %%
from sklearn.tree import DecisionTreeRegressor
d_model=DecisionTreeRegressor()
d_model.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
accuracy_DecisionTree = d_model.score(X_test, y_test)
accuracy_DecisionTree
# Out:
# 0.9571252592134591

# %% [markdown]
# TRAIN AN RANDOMFOREST REGRESSOR MODEL

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf_model=RandomForestRegressor(max_depth=5,n_estimators=100)

# %%
rf_model.fit(X_train,y_train)
# Out:
# RandomForestRegressor(max_depth=5)

# %%
accuracy_RandomForest= rf_model.score(X_test, y_test)
accuracy_RandomForest
# Out:
# 0.6204874429675481

# %% [markdown]
# TRAIN AN XG-BOOST REGRESSOR MODEL

# %%
# !pip install xgboost
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: xgboost in /usr/local/lib/python3.7/dist-packages (0.90)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from xgboost) (1.4.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from xgboost) (1.21.6)

# %%
from xgboost import XGBRegressor

# %%
xgb_model=XGBRegressor()
xgb_model.fit(X_train,y_train)
# Out:
# [16:48:34] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGBRegressor()

# %%
accuracy_XGBoost = xgb_model.score(X_test, y_test)
accuracy_XGBoost
# Out:
# 0.7456490477763406

# %% [markdown]
# Tuning Hyperparameter

# %%
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV

# %%
# Function to give best model score and parameters
def best_model(model):
    print(model.best_score_)    
    print(model.best_params_)
    print(model.best_estimator_)

# %%
# Fit Extreme Gradient boosting Regressor
param_grid = {'max_depth': [5,6,7,8], 'gamma': [0.01,0.001,0.001],'min_child_weight':[1,5,10], 'learning_rate': [0.05,0.1, 0.2, 0.3], 'n_estimators':[5,10,20,100]}
xgb_grid = GridSearchCV(XGBRegressor(), param_grid, cv=5, refit=True, verbose=0)
xgb_grid.fit(X_train,y_train)
best_model(xgb_grid)
# Out:
# [16:53:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [16:53:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [16:53:24] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [16:53:26] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [16:53:29] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [16:53:32] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [16:53:35] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [16:53:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [16:53:43] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [16:53:47] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [16:53:51] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [16:53:58] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [16:54:07] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [16:54:16] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [16:54:23] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [16:54:30] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [16:55:05] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [16:55:35] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [16:56:05] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [16:56:35] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [16:57:07] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [16:57:11] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [16:57:13] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [16:57:16] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [16:57:18] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [16:57:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [16:57:26] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [16:57:31] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [16:57:35] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [16:57:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [16:57:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [16:57:51] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [16:57:58] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [16:58:05] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [16:58:15] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [16:58:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [16:58:51] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [16:59:28] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [16:59:59] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [17:00:29] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [17:01:00] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [17:01:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [17:01:05] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [17:01:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [17:01:10] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [17:01:13] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [17:01:17] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [17:01:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [17:01:25] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [17:01:29] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [17:01:33] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [17:01:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [17:01:48] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [17:01:55] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [17:02:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [17:02:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [17:02:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [17:03:09] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [17:03:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [17:04:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [17:04:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [17:04:43] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [17:04:46] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [17:04:49] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [17:04:52] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [17:04:55] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [17:05:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [17:05:14] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [17:05:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [17:05:30] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [17:05:37] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [17:05:48] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [17:05:56] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [17:06:05] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [17:06:13] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [17:06:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [17:06:58] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [17:07:35] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [17:08:12] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [17:08:48] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [17:09:24] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [17:09:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [17:09:30] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [17:09:33] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [17:09:36] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [17:09:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [17:09:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [17:09:49] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [17:09:54] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [17:09:58] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [17:10:03] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [17:10:11] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [17:10:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [17:10:28] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [17:10:36] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [17:10:45] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [17:11:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [17:11:54] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [17:12:30] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [17:13:06] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [17:13:43] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [17:13:46] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [17:13:49] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [17:13:52] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [17:13:55] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [17:13:58] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [17:14:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [17:14:07] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [17:14:12] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [17:14:17] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [17:14:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [17:14:30] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [17:14:38] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [17:14:46] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [17:14:55] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [17:15:03] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [17:15:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-108-92f66b57c85a> in <module>()
#       2 param_grid = {'max_depth': [5,6,7,8], 'gamma': [0.01,0.001,0.001],'min_child_weight':[1,5,10], 'learning_rate': [0.05,0.1, 0.2, 0.3], 'n_estimators':[5,10,20,100]}
#       3 xgb_grid = GridSearchCV(XGBRegressor(), param_grid, cv=5, refit=True, verbose=0)
# ----> 4 xgb_grid.fit(X_train,y_train)
#       5 best_model(xgb_grid)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     889                 return results
#     890
# --> 891             self._run_search(evaluate_candidates)
#     892
#     893             # multimetric is determined here because in the case of a callable
#
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_search.py in _run_search(self, evaluate_candidates)
#    1390     def _run_search(self, evaluate_candidates):
#    1391         """Search all candidates in param_grid"""
# -> 1392         evaluate_candidates(ParameterGrid(self.param_grid))
#    1393
#    1394
#
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_search.py in evaluate_candidates(candidate_params, cv, more_results)
#     849                     )
#     850                     for (cand_idx, parameters), (split_idx, (train, test)) in product(
# --> 851                         enumerate(candidate_params), enumerate(cv.split(X, y, groups))
#     852                     )
#     853                 )
#
# /usr/local/lib/python3.7/dist-packages/joblib/parallel.py in __call__(self, iterable)
#    1044                 self._iterating = self._original_iterator is not None
#    1045
# -> 1046             while self.dispatch_one_batch(iterator):
#    1047                 pass
#    1048
#
# /usr/local/lib/python3.7/dist-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     859                 return False
#     860             else:
# --> 861                 self._dispatch(tasks)
#     862                 return True
#     863
#
# /usr/local/lib/python3.7/dist-packages/joblib/parallel.py in _dispatch(self, batch)
#     777         with self._lock:
#     778             job_idx = len(self._jobs)
# --> 779             job = self._backend.apply_async(batch, callback=cb)
#     780             # A job can complete so quickly than its callback is
#     781             # called before we get here, causing self._jobs to
#
# /usr/local/lib/python3.7/dist-packages/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     206     def apply_async(self, func, callback=None):
#     207         """Schedule a func to be run"""
# --> 208         result = ImmediateResult(func)
#     209         if callback:
#     210             callback(result)
#
# /usr/local/lib/python3.7/dist-packages/joblib/_parallel_backends.py in __init__(self, batch)
#     570         # Don't delay the application, to avoid keeping the input
#     571         # arguments in memory
# --> 572         self.results = batch()
#     573
#     574     def get(self):
#
# /usr/local/lib/python3.7/dist-packages/joblib/parallel.py in __call__(self)
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     262             return [func(*args, **kwargs)
# --> 263                     for func, args, kwargs in self.items]
#     264
#     265     def __reduce__(self):
#
# /usr/local/lib/python3.7/dist-packages/joblib/parallel.py in <listcomp>(.0)
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     262             return [func(*args, **kwargs)
# --> 263                     for func, args, kwargs in self.items]
#     264
#     265     def __reduce__(self):
#
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/fixes.py in __call__(self, *args, **kwargs)
#     214     def __call__(self, *args, **kwargs):
#     215         with config_context(**self.config):
# --> 216             return self.function(*args, **kwargs)
#     217
#     218
#
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     678             estimator.fit(X_train, **fit_params)
#     679         else:
# --> 680             estimator.fit(X_train, y_train, **fit_params)
#     681
#     682     except Exception:
#
# /usr/local/lib/python3.7/dist-packages/xgboost/sklearn.py in fit(self, X, y, sample_weight, eval_set, eval_metric, early_stopping_rounds, verbose, xgb_model, sample_weight_eval_set, callbacks)
#     394                               evals_result=evals_result, obj=obj, feval=feval,
#     395                               verbose_eval=verbose, xgb_model=xgb_model,
# --> 396                               callbacks=callbacks)
#     397
#     398         if evals_result:
#
# /usr/local/lib/python3.7/dist-packages/xgboost/training.py in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, learning_rates)
#     214                            evals=evals,
#     215                            obj=obj, feval=feval,
# --> 216                            xgb_model=xgb_model, callbacks=callbacks)
#     217
#     218
#
# /usr/local/lib/python3.7/dist-packages/xgboost/training.py in _train_internal(params, dtrain, num_boost_round, evals, obj, feval, xgb_model, callbacks)
#      72         # Skip the first update if it is a recovery step.
#      73         if version % 2 == 0:
# ---> 74             bst.update(dtrain, i, obj)
#      75             bst.save_rabit_checkpoint()
#      76             version += 1
#
# /usr/local/lib/python3.7/dist-packages/xgboost/core.py in update(self, dtrain, iteration, fobj)
#    1107         if fobj is None:
#    1108             _check_call(_LIB.XGBoosterUpdateOneIter(self.handle, ctypes.c_int(iteration),
# -> 1109                                                     dtrain.handle))
#    1110         else:
#    1111             pred = self.predict(dtrain)
#
# KeyboardInterrupt:

# %%
# Fit Extreme Gradient Boost Regressor
XGB = XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,colsample_bytree=1, gamma=0.01, learning_rate=0.1, max_delta_step=0,max_depth=5,
                    min_child_weight=5, missing=None, n_estimators=100,n_jobs=1, random_state=0,reg_alpha=0, 
                    reg_lambda=1, scale_pos_weight=1, seed=None, silent=True, subsample=1)
XGB.fit(X_train,y_train)

# base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#              min_child_weight=1, missing=nan, monotone_constraints='()',
#              n_estimators=100, n_jobs=2, num_parallel_tree=1, random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#              tree_method='exact', validate_parameters=1, verbosity=None)
# Out:
# XGBRegressor(gamma=0.01, max_depth=5, min_child_weight=5, silent=True)

# %%
XGB.score(X_test,y_test)
# Out:
# 0.8752321365587605

# %% [markdown]
# COMPARE MODELS AND CALCULATE REGRESSION KPIs

# %%
y_predict_linear = linear_regmodel.predict(X_test)

fig = sns.regplot(y_predict_linear, y_test, color = 'red', marker = "^")
fig.set(title = "Linear Regression Model", xlabel = "Predicted Weekly_Sales", ylabel = "Actual Price of Weekly_Sales")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning:
#
# Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# [Text(0, 0.5, 'Actual Price of Weekly_Sales'),
#  Text(0.5, 0, 'Predicted Weekly_Sales'),
#  Text(0.5, 1.0, 'Linear Regression Model')]

# %%
RMSE= float(format(np.sqrt(mean_squared_error(y_test, y_predict_linear)), ".3f"))
MSE= mean_squared_error(y_test, y_predict_linear)
MAE= mean_absolute_error(y_test, y_predict_linear)
r2= r2_score(y_test, y_predict_linear)

print('RMSE =',RMSE, '\nMSE =',MSE, '\nMAE =',MAE, '\nR2 =', r2)
# Out:
# RMSE = 21710.991
# MSE = 471367117.86385465
# MAE = 14581.874190843462
# R2 = 0.08831467380915592

# %%
y_predict_RandomForest = rf_model.predict(X_test)

fig = sns.regplot(y_predict_RandomForest, y_test, color = 'blue', marker = "s")
fig.set(title = "Random Forest Regression Model", xlabel = "Predicted Weekly_Sales", ylabel = "Actual Price of Weekly_Sales")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning:
#
# Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# [Text(0, 0.5, 'Actual Price of Weekly_Sales'),
#  Text(0.5, 0, 'Predicted Weekly_Sales'),
#  Text(0.5, 1.0, 'Random Forest Regression Model')]

# %%
RMSE= float(format(np.sqrt(mean_squared_error(y_test, y_predict_RandomForest)), ".3f"))
MSE= mean_squared_error(y_test, y_predict_RandomForest)
MAE= mean_absolute_error(y_test, y_predict_RandomForest)
r2= r2_score(y_test, y_predict_RandomForest)

print('RMSE =',RMSE, '\nMSE =',MSE, '\nMAE =',MAE, '\nR2 =', r2)
# Out:
# RMSE = 14007.81
# MSE = 196218733.65995303
# MAE = 8740.970518321446
# R2 = 0.6204874429675481

# %%
y_predict_XGBoost = xgb_model.predict(X_test)

fig = sns.regplot(y_predict_XGBoost, y_test, color = 'green', marker = "D")
fig.set(title = "XGBoost Model", xlabel = "Predicted Weekly_Sales", ylabel = "Actual Price of Weekly_Sales")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning:
#
# Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# [Text(0, 0.5, 'Actual Price of Weekly_Sales'),
#  Text(0.5, 0, 'Predicted Weekly_Sales'),
#  Text(0.5, 1.0, 'XGBoost Model')]

# %%
RMSE = float(format(np.sqrt(mean_squared_error(y_test, y_predict_XGBoost)), ".3f"))
MSE = mean_squared_error(y_test, y_predict_XGBoost)
MAE = mean_absolute_error(y_test, y_predict_XGBoost)
r2 = r2_score(y_test, y_predict_XGBoost)

print('RMSE =',RMSE, '\nMSE =',MSE, '\nMAE =',MAE, '\nR2 =', r2)
# Out:
# RMSE = 11467.635
# MSE = 131506641.41598356
# MAE = 6903.0491659891
# R2 = 0.7456490477763406

# %%
y_predict_XGBoost2 = XGB.predict(X_test)

fig = sns.regplot(y_predict_XGBoost, y_test, color = 'Magenta', marker = "D")
fig.set(title = "XGBoost Model 2", xlabel = "Predicted Weekly_Sales", ylabel = "Actual Price of Weekly_Sales")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning:
#
# Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# [Text(0, 0.5, 'Actual Price of Weekly_Sales'),
#  Text(0.5, 0, 'Predicted Weekly_Sales'),
#  Text(0.5, 1.0, 'XGBoost Model 2')]

# %%
RMSE = float(format(np.sqrt(mean_squared_error(y_test, y_predict_XGBoost2)), ".3f"))
MSE = mean_squared_error(y_test, y_predict_XGBoost2)
MAE = mean_absolute_error(y_test, y_predict_XGBoost2)
r2 = r2_score(y_test, y_predict_XGBoost2)

print('RMSE =',RMSE, '\nMSE =',MSE, '\nMAE =',MAE, '\nR2 =', r2)
# Out:
# RMSE = 8031.719
# MSE = 64508516.81253999
# MAE = 4695.448956038657
# R2 = 0.8752321365587605

# %%
y_predict_dtree = d_model.predict(X_test)

fig = sns.regplot(y_predict_dtree, y_test, color = 'yellow', marker = "D")
fig.set(title = "XGBoost Model", xlabel = "Predicted Weekly_Sales", ylabel = "Actual Price of Weekly_Sales")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning:
#
# Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# [Text(0, 0.5, 'Actual Price of Weekly_Sales'),
#  Text(0.5, 0, 'Predicted Weekly_Sales'),
#  Text(0.5, 1.0, 'XGBoost Model')]

# %%
RMSE = float(format(np.sqrt(mean_squared_error(y_test, y_predict_dtree)), ".3f"))
MSE = mean_squared_error(y_test, y_predict_dtree)
MAE = mean_absolute_error(y_test, y_predict_dtree)
r2 = r2_score(y_test, y_predict_dtree)

print('RMSE =',RMSE, '\nMSE =',MSE, '\nMAE =',MAE, '\nR2 =', r2)
# Out:
# RMSE = 4708.233
# MSE = 22167454.507742178
# MAE = 1827.428403902871
# R2 = 0.9571252592134591

# %% [markdown]
# Now we are going to predict test data using XGB model 2

# %%
X_test_data
# Out:
# array([[1, 1, 44, ..., 0, 1, 151315],
#        [1, 1, 45, ..., 0, 1, 151315],
#        [1, 1, 46, ..., 0, 1, 151315],
#        ...,
#        [45, 98, 28, ..., 0, 2, 118221],
#        [45, 98, 29, ..., 0, 2, 118221],
#        [45, 98, 30, ..., 0, 2, 118221]], dtype=object)

# %%
XGB.predict(X_test_data)
# Out:
# array([24033.367 , 23706.053 , 24845.842 , ...,  2392.0242,  2565.831 ,
#         2308.8516], dtype=float32)

# %%
test_with_feat.shape
# Out:
# (115064, 20)

# %%
test_data_predict=XGB.predict(X_test_data)

# %%
len(test_data_predict)
# Out:
# 115064

# %%
test_predicted=pd.DataFrame(test_data_predict,columns=["Weekly_sales_predicted"])

# %%
test_predicted
# Out:
#         Weekly_sales_predicted
# 0                 24033.367188
# 1                 23706.052734
# 2                 24845.841797
# 3                 24682.837891
# 4                 28417.681641
# ...                        ...
# 115059             1665.826294
# 115060             2735.563232
# 115061             2392.024170
# 115062             2565.831055
# 115063             2308.851562
#
# [115064 rows x 1 columns]
